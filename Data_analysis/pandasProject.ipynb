# %% [markdown]
# #### Project using pandas,Numpy --> GOT series Extraction

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'Game_of_Thrones (1).csv')

# %%
df.head()
print(df.shape)
# Out:
# (73, 19)

# %%
for i in range(10):
    print(df.loc[i]['Original Air Date'])
# Out:
# 17-Apr-2011
# 24-Apr-2011
# 1-May-2011
# 8-May-2011
# 15-May-2011
# 22-May-2011
# 29-May-2011
# 5-Jun-2011
# 12-Jun-2011
# 19-Jun-2011

# %%
def extract_year(date_string):     # Receives ONE date
    return int(date_string[-4:])   # Extract year from that ONE date

df['Year'] = df['Original Air Date'].apply(extract_year)
