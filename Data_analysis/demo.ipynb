# %% [markdown]
# ### This is the first setup in jupyter
#
# ---
# - task 1 : checking the setup of jupyter how to run

# %%
print("Hello World")
# Out:
# Hello World

# %%
a=3
b=3
print("sm=",a+b)
# Out:
# sm= 6

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
arr = np.array([1,3,5,7,9])
result = arr * 10

# %%
print(result)
# Out:
# [10 30 50 70 90]

# %%
mean_val = np.array(result)
print(f"Mean val : {mean_val}")
# Out:
# Mean val : [10 30 50 70 90]

# %%
from abc import ABC, abstractmethod
class Greet(ABC):
    @abstractmethod
    def say_hello(self):
        pass
class English(Greet):
    def say_hello(self):
        return "Hello There!"

g1 = English()
print (g1.say_hello())
# Out:
# Hello There!
